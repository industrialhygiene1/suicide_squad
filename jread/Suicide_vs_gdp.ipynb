# %%
#Dependencies

import requests
import json
from matplotlib import pyplot as plt
from scipy.stats import linregress
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# The path to our CSV file
file_gdp = "out.csv"

# Read Suicide Data our Kickstarter data into pandas
df = pd.read_csv(file_gdp)
df.head()
# Out:
#    Unnamed: 0  country  year     sex          age  suicides_no  population  \
# 0           0  Albania  1987    male  15-24 years           21      312900
# 1           1  Albania  1987    male  35-54 years           16      308000
# 2           2  Albania  1987  female  15-24 years           14      289700
# 3           3  Albania  1987    male    75+ years            1       21800
# 4           4  Albania  1987    male  25-34 years            9      274300
#
#    suicides/100k pop country-year  HDI for year   gdp_for_year  \
# 0               6.71  Albania1987           NaN  2,156,624,900
# 1               5.19  Albania1987           NaN  2,156,624,900
# 2               4.83  Albania1987           NaN  2,156,624,900
# 3               4.59  Albania1987           NaN  2,156,624,900
# 4               3.28  Albania1987           NaN  2,156,624,900
#
#    gdp_per_capita ($)       generation
# 0                 796     Generation X
# 1                 796           Silent
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'country', 'year', 'sex', 'age', 'suicides_no',
#        'population', 'suicides/100k pop', 'country-year', 'HDI for year',
#        ' gdp_for_year', 'gdp_per_capita ($)', 'generation'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27820 entries, 0 to 27819
# Data columns (total 12 columns):
# country               27820 non-null object
# year                  27820 non-null int64
# sex                   27820 non-null object
# age                   27820 non-null object
# suicides_no           27820 non-null int64
# population            27820 non-null int64
# suicides/100k pop     27820 non-null float64
# country-year          27820 non-null object
# HDI for year          8364 non-null float64
#  gdp_for_year ($)     27820 non-null object
# gdp_per_capita ($)    27820 non-null int64
# generation            27820 non-null object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 2.5+ MB

# %%
df = df.groupby('country-year').agg({' gdp_for_year':'first', 'population':'sum'}).reset_index()
print (df)
# Out:
#                  country-year    gdp_for_year  population
# 0                 Albania1987   2,156,624,900     2709600
# 1                 Albania1988   2,126,000,000     2764300
# 2                 Albania1989   2,335,124,988     2803100
# 3                 Albania1992     709,452,584     2822500
# 4                 Albania1993   1,228,071,038     2807300
# 5                 Albania1994   1,985,673,798     2849300
# 6                 Albania1995   2,424,499,009     2903400
# 7                 Albania1996   3,314,898,292     2940200
# 8                 Albania1997   2,359,903,108     2977300
# 9                 Albania1998   2,707,123,772     3012700
# 10                Albania1999   3,414,760,915     3029700
# 11                Albania2000   3,632,043,908     2796300
# 12                Albania2001   4,060,758,804     2799349
# 13                Albania2002   4,435,078,648     2818839
# 14                Albania2003   5,746,945,913     2843929
# ...

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 96 entries, 193 to 9450
# Data columns (total 39 columns):
# Country       96 non-null int64
# Admin1        0 non-null float64
# SubDiv        0 non-null float64
# Year          96 non-null int64
# List          96 non-null object
# Cause         96 non-null object
# Sex           96 non-null int64
# Frmat         96 non-null int64
# IM_Frmat      96 non-null int64
# Deaths1       96 non-null int64
# Deaths2       96 non-null float64
# Deaths3       96 non-null float64
# Deaths4       50 non-null float64
# Deaths5       50 non-null float64
# Deaths6       50 non-null float64
# Deaths7       96 non-null float64
# Deaths8       88 non-null float64
# Deaths9       96 non-null float64
# Deaths10      88 non-null float64
# Deaths11      96 non-null float64
# Deaths12      88 non-null float64
# Deaths13      96 non-null float64
# Deaths14      88 non-null float64
# Deaths15      96 non-null float64
# Deaths16      88 non-null float64
# ...

# %%
# The path to our CSV file
file_gdp2 = "Morticd10_part2.csv"

# Read Suicide Data our Kickstarter data into pandas
df2 = pd.read_csv(file_gdp2)
df2.head()
# Out:
#    Country  Admin1 SubDiv  Year List Cause  Sex  Frmat  IM_Frmat  Deaths1  \
# 0     1400     NaN    NaN  2005  101  1000    1      7         8      386
# 1     1400     NaN    NaN  2005  101  1000    2      7         8      287
# 2     1400     NaN    NaN  2005  101  1001    1      7         8       29
# 3     1400     NaN    NaN  2005  101  1001    2      7         8       21
# 4     1400     NaN    NaN  2005  101  1002    1      7         8        0
#
#       ...      Deaths21  Deaths22  Deaths23  Deaths24  Deaths25  Deaths26  \
# 0     ...         136.0       NaN       NaN       NaN       NaN       0.0
# 1     ...         163.0       NaN       NaN       NaN       NaN       0.0
# 2     ...          13.0       NaN       NaN       NaN       NaN       0.0
# 3     ...          16.0       NaN       NaN       NaN       NaN       0.0
# 4     ...           0.0       NaN       NaN       NaN       NaN       0.0
#
#    IM_Deaths1  IM_Deaths2  IM_Deaths3  IM_Deaths4
# ...

# %%
cause_list_csv = "cause_list.csv"

# Read Suicide Data our Kickstarter data into pandas
causes = pd.read_csv(cause_list_csv)
causes.head()
# Out:
#   Cause
# 0  1101
# 1   X60
# 2   X61
# 3   X62
# 4   X63

# %%
organized_crime_data_2017_df["Level of Crime"] = 
np.where(organized_crime_data_2017_df["crime"].isin(Cause), "Minor", "Major")

df22 = df2[df2['Cause'] == ""]
df22.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 156 entries, 193 to 15465
# Data columns (total 39 columns):
# Country       156 non-null int64
# Admin1        0 non-null float64
# SubDiv        0 non-null object
# Year          156 non-null int64
# List          156 non-null object
# Cause         156 non-null object
# Sex           156 non-null int64
# Frmat         156 non-null int64
# IM_Frmat      156 non-null int64
# Deaths1       156 non-null int64
# Deaths2       136 non-null float64
# Deaths3       136 non-null float64
# Deaths4       74 non-null float64
# Deaths5       74 non-null float64
# Deaths6       74 non-null float64
# Deaths7       136 non-null float64
# Deaths8       114 non-null float64
# Deaths9       136 non-null float64
# Deaths10      114 non-null float64
# Deaths11      136 non-null float64
# Deaths12      114 non-null float64
# Deaths13      136 non-null float64
# Deaths14      114 non-null float64
# Deaths15      136 non-null float64
# ...

# %%
frames = [df1, df22]
result = pd.concat(frames)

# %%
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 252 entries, 193 to 15465
# Data columns (total 39 columns):
# Country       252 non-null int64
# Admin1        0 non-null float64
# SubDiv        0 non-null object
# Year          252 non-null int64
# List          252 non-null object
# Cause         252 non-null object
# Sex           252 non-null int64
# Frmat         252 non-null int64
# IM_Frmat      252 non-null int64
# Deaths1       252 non-null int64
# Deaths2       232 non-null float64
# Deaths3       232 non-null float64
# Deaths4       124 non-null float64
# Deaths5       124 non-null float64
# Deaths6       124 non-null float64
# Deaths7       232 non-null float64
# Deaths8       202 non-null float64
# Deaths9       232 non-null float64
# Deaths10      202 non-null float64
# Deaths11      232 non-null float64
# Deaths12      202 non-null float64
# Deaths13      232 non-null float64
# Deaths14      202 non-null float64
# Deaths15      232 non-null float64
# ...

# %%
suicide_data = result[["Country", "Year", "Cause", "Sex", "Deaths1"]]
suicide_data.describe()
# Out:
#            Country         Year         Sex       Deaths1
# count   252.000000   252.000000  252.000000    252.000000
# mean   3582.515873  2006.428571    1.500000   3371.222222
# std     925.944563     4.985123    0.500995   8897.217523
# min    1400.000000  1996.000000    1.000000      0.000000
# 25%    3080.000000  2002.000000    1.000000      4.000000
# 50%    4018.000000  2007.000000    1.500000     79.000000
# 75%    4275.000000  2011.000000    2.000000   1769.250000
# max    4303.000000  2015.000000    2.000000  48251.000000

# %%
df.count()
# Out:
# Country       1388106
# Admin1          84173
# SubDiv              0
# Year          1388106
# List          1388106
# Cause         1388106
# Sex           1388106
# Frmat         1388106
# IM_Frmat      1388106
# Deaths1       1388106
# Deaths2       1387983
# Deaths3       1387983
# Deaths4       1328926
# Deaths5       1328926
# Deaths6       1328926
# Deaths7       1387983
# Deaths8       1387187
# Deaths9       1387983
# Deaths10      1387187
# Deaths11      1387983
# Deaths12      1387187
# Deaths13      1387983
# Deaths14      1387187
# Deaths15      1387983
# Deaths16      1387187
# Deaths17      1387983
# Deaths18      1387187
# Deaths19      1387983
# Deaths20      1387187
# Deaths21      1387983
# Deaths22      1384744
# Deaths23      1384744
# Deaths24      1185179
# Deaths25      1185179
# Deaths26      1387983
# IM_Deaths1    1387983
# IM_Deaths2     956982
# IM_Deaths3     983359
# IM_Deaths4     983359
# dtype: int64
