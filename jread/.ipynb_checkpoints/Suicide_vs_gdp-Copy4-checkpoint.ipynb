# %%
#Dependencies
import requests
import json
import gmaps
from matplotlib import pyplot as plt
from scipy import stats
from scipy.stats import linregress
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# The path to our CSV file
file_gdp = "suicides_vs_gdp_o.csv"

# Read Suicide Data our Kickstarter data into pandas
su_vs_gdp_o_df = pd.read_csv(file_gdp)
su_vs_gdp_o_df.head()
# Out:
#    index  country  year     sex          age  suicides_no  population  \
# 0      0  Albania  1987    male  15-24 years           21      312900
# 1      1  Albania  1987    male  35-54 years           16      308000
# 2      2  Albania  1987  female  15-24 years           14      289700
# 3      3  Albania  1987    male    75+ years            1       21800
# 4      4  Albania  1987    male  25-34 years            9      274300
#
#    suicides/100k pop country-year    year_gdp gdp_per_capita ($)  \
# 0               6.71  Albania1987  2160000000           $796.00
# 1               5.19  Albania1987  2160000000           $796.00
# 2               4.83  Albania1987  2160000000           $796.00
# 3               4.59  Albania1987  2160000000           $796.00
# 4               3.28  Albania1987  2160000000           $796.00
#
#         generation
# 0     Generation X
# 1           Silent
# 2     Generation X
# 3  G.I. Generation
# 4          Boomers

# %%
su_vs_gdp_o_df.columns
# Out:
# Index(['index', 'country', 'year', 'sex', 'age', 'suicides_no', 'population',
#        'suicides/100k pop', 'country-year', 'year_gdp', 'gdp_per_capita ($)',
#        'generation'],
#       dtype='object')

# %%
su_vs_gdp_o_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27820 entries, 0 to 27819
# Data columns (total 12 columns):
# index                 27820 non-null int64
# country               27820 non-null object
# year                  27820 non-null int64
# sex                   27820 non-null object
# age                   27820 non-null object
# suicides_no           27820 non-null int64
# population            27820 non-null int64
# suicides/100k pop     27820 non-null float64
# country-year          27820 non-null object
# year_gdp              27820 non-null int64
# gdp_per_capita ($)    27820 non-null object
# generation            27820 non-null object
# dtypes: float64(1), int64(5), object(6)
# memory usage: 2.5+ MB

# %%
su_vs_gdp_df = su_vs_gdp_o_df.groupby('country-year').agg({'country':'first', 'year':'first', 
                                                           'suicides_no':'sum','population':'sum', 
                                                           'suicides/100k pop':'sum',
                                                           'year_gdp':'first',
                                                           'gdp_per_capita ($)':'first'}).reset_index()
su_vs_gdp_df.head()
# Out:
#   country-year  country  year  suicides_no  population  suicides/100k pop  \
# 0  Albania1987  Albania  1987           73     2709600              31.85
# 1  Albania1988  Albania  1988           63     2764300              32.46
# 2  Albania1989  Albania  1989           68     2803100              33.40
# 3  Albania1992  Albania  1992           47     2822500              18.00
# 4  Albania1993  Albania  1993           73     2807300              32.56
#
#      year_gdp gdp_per_capita ($)
# 0  2160000000           $796.00
# 1  2130000000           $769.00
# 2  2340000000           $833.00
# 3   709000000           $251.00
# 4  1230000000           $437.00

# %%
su_vs_gdp_df.to_csv('cleaned_su_vs_gdp.csv')

# %%
file_gdp2 = "cleaned_su_vs_gdp.csv"

su_vs_gdp_c_df = pd.read_csv(file_gdp2)
su_vs_gdp_c_df.head(45)
# Out:
#     Unnamed: 0             country-year              country  year  \
# 0            0              Albania1987              Albania  1987
# 1            1              Albania1988              Albania  1988
# 2            2              Albania1989              Albania  1989
# 3            3              Albania1992              Albania  1992
# 4            4              Albania1993              Albania  1993
# 5            5              Albania1994              Albania  1994
# 6            6              Albania1995              Albania  1995
# 7            7              Albania1996              Albania  1996
# 8            8              Albania1997              Albania  1997
# 9            9              Albania1998              Albania  1998
# 10          10              Albania1999              Albania  1999
# 11          11              Albania2000              Albania  2000
# 12          12              Albania2001              Albania  2001
# 13          13              Albania2002              Albania  2002
# 14          14              Albania2003              Albania  2003
# 15          15              Albania2004              Albania  2004
# 16          16              Albania2005              Albania  2005
# 17          17              Albania2006              Albania  2006
# 18          18              Albania2007              Albania  2007
# 19          19              Albania2008              Albania  2008
# 20          20              Albania2009              Albania  2009
# 21          21              Albania2010              Albania  2010
# 22          22  Antigua and Barbuda1985  Antigua and Barbuda  1985
# 23          23  Antigua and Barbuda1986  Antigua and Barbuda  1986
# 24          24  Antigua and Barbuda1987  Antigua and Barbuda  1987
# 25          25  Antigua and Barbuda1988  Antigua and Barbuda  1988
# 26          26  Antigua and Barbuda1989  Antigua and Barbuda  1989
# 27          27  Antigua and Barbuda1990  Antigua and Barbuda  1990
# 28          28  Antigua and Barbuda1991  Antigua and Barbuda  1991
# 29          29  Antigua and Barbuda1992  Antigua and Barbuda  1992
# 30          30  Antigua and Barbuda1993  Antigua and Barbuda  1993
# 31          31  Antigua and Barbuda1994  Antigua and Barbuda  1994
# 32          32  Antigua and Barbuda1995  Antigua and Barbuda  1995
# 33          33  Antigua and Barbuda1998  Antigua and Barbuda  1998
# 34          34  Antigua and Barbuda1999  Antigua and Barbuda  1999
# 35          35  Antigua and Barbuda2000  Antigua and Barbuda  2000
# 36          36  Antigua and Barbuda2001  Antigua and Barbuda  2001
# 37          37  Antigua and Barbuda2002  Antigua and Barbuda  2002
# 38          38  Antigua and Barbuda2003  Antigua and Barbuda  2003
# 39          39  Antigua and Barbuda2004  Antigua and Barbuda  2004
# 40          40  Antigua and Barbuda2005  Antigua and Barbuda  2005
# 41          41  Antigua and Barbuda2006  Antigua and Barbuda  2006
# 42          42  Antigua and Barbuda2007  Antigua and Barbuda  2007
# 43          43  Antigua and Barbuda2008  Antigua and Barbuda  2008
# 44          44  Antigua and Barbuda2009  Antigua and Barbuda  2009
#
#     suicides_no  population  suicides/100k pop     year_gdp gdp_per_capita ($)
# 0            73     2709600              31.85   2160000000           $796.00
# 1            63     2764300              32.46   2130000000           $769.00
# 2            68     2803100              33.40   2340000000           $833.00
# 3            47     2822500              18.00    709000000           $251.00
# 4            73     2807300              32.56   1230000000           $437.00
# 5            50     2849300              32.18   1990000000           $697.00
# 6            88     2903400              40.55   2420000000           $835.00
# 7            89     2940200              43.62   3310000000         $1,127.00
# 8           170     2977300              77.43   2360000000           $793.00
# 9           154     3012700              66.52   2710000000           $899.00
# 10          139     3029700              69.81   3410000000         $1,127.00
# 11           54     2796300              30.70   3630000000         $1,299.00
# 12          119     2799349              50.62   4060000000         $1,451.00
# 13          133     2818839              62.51   4440000000         $1,573.00
# 14          124     2843929              58.60   5750000000         $2,021.00
# 15          146     2874991              65.39   7310000000         $2,544.00
# 16            0     2783320               0.00   8160000000         $2,931.00
# 17            0     2780176               0.00   8990000000         $3,235.00
# 18          124     2770344              65.85  10700000000         $3,863.00
# 19          160     2757059              71.05  12900000000         $4,672.00
# 20            0     2745735               0.00  12000000000         $4,387.00
# 21           96     2736025              41.66  11900000000         $4,359.00
# 22            0       62574               0.00    241000000         $3,850.00
# 23            0       61270               0.00    290000000         $4,740.00
# 24            0       60261               0.00    337000000         $5,595.00
# 25            0       59564               0.00    399000000         $6,693.00
# 26            0       59238               0.00    439000000         $7,407.00
# 27            1       59334              17.24    459000000         $7,744.00
# 28            0       60394               0.00    482000000         $7,976.00
# 29            0       61741               0.00    499000000         $8,087.00
# 30            1       63315              15.00    535000000         $8,453.00
# 31            0       65044               0.00    589000000         $9,062.00
# 32            0       66846               0.00    577000000         $8,636.00
# 33            0       72225               0.00    728000000        $10,078.00
# 34            0       73832               0.00    766000000        $10,378.00
# 35            2       75326              39.97    830000000        $11,021.00
# 36            2       76497              19.45    801000000        $10,468.00
# 37            0       77588               0.00    815000000        $10,499.00
# 38            1       78658              27.82    856000000        $10,878.00
# 39            2       79722              36.06    920000000        $11,535.00
# 40            0       80809               0.00   1020000000        $12,649.00
# 41            0       81973               0.00   1160000000        $14,114.00
# 42            1       83131               7.98   1310000000        $15,775.00
# 43            0       84273               0.00   1370000000        $16,238.00
# 44            0       85405               0.00   1220000000        $14,335.00

# %%
x_axis = su_vs_gdp_c_df['year_gdp']
y_axis = su_vs_gdp_c_df['suicides/100k pop']
plt.grid(True)

plt.savefig("Sui_vs_GDP_Scatter.png")


plt.scatter(x_axis, y_axis)

# %%
(slope, intercept, _, _, _) = linregress(x_axis, y_axis)
fit = slope * x_axis + intercept

# %%
fig, ax = plt.subplots()

fig.suptitle("Suicide Rate vs GDP Regression", fontsize=16, fontweight="bold")

ax.set_xlim(0, 17500000000000)
ax.set_ylim(0, 700)

ax.set_xlabel("GDP (x10 to the 13th Power)")
ax.set_ylabel("Suicide Rate per 100K People")

ax.plot(x_axis, y_axis, linewidth=0, marker='o')
ax.plot(x_axis, fit, 'b--')
plt.grid(True)

plt.savefig("Sui_vs_GDP_regression.png")

plt.show()

# %%
(t_stat, p) = stats.ttest_ind(x_axis, y_axis, equal_var=False)
p
# Out:
# 3.402836006166142e-47

# %%
su_vs_gdp_2015_df = su_vs_gdp_c_df.query("year == '2015'")
su_vs_gdp_2015_nous_df = su_vs_gdp_2015_df.query("country != 'United States'")
su_vs_gdp_2015_nous_df.head()
# Out:
#      Unnamed: 0             country-year              country  year  \
# 48           48  Antigua and Barbuda2015  Antigua and Barbuda  2015
# 79           79            Argentina2015            Argentina  2015
# 103         103              Armenia2015              Armenia  2015
# 148         148            Australia2015            Australia  2015
# 179         179              Austria2015              Austria  2015
#
#      suicides_no  population  suicides/100k pop       year_gdp  \
# 48             1       91889              15.62     1360000000
# 79          3073    39699624             112.13   595000000000
# 103           74     2795335              45.28    10600000000
# 148         3027    22240785             154.18  1350000000000
# 179         1251     8219386             194.62   382000000000
#
#     gdp_per_capita ($)
# 48         $14,853.00
# 79         $14,981.00
# 103         $3,775.00
# 148        $60,656.00
# 179        $46,484.00

# %%
x_axis_2015 = su_vs_gdp_2015_nous_df['year_gdp']
y_axis_2015 = su_vs_gdp_2015_nous_df['suicides/100k pop']

plt.grid(True)

plt.savefig("Sui_vs_GDP_Scatter_2015.png")

plt.scatter(x_axis_2015, y_axis_2015)

# %%
(slope, intercept, _, _, _) = linregress(x_axis_2015, y_axis_2015)
fit = slope * x_axis_2015 + intercept

# %%
fig, ax_2015 = plt.subplots()

fig.suptitle("Suicide Rate vs GDP Regression 2015", fontsize=16, fontweight="bold")

ax_2015.set_xlim(0, 4500000000000)
ax_2015.set_ylim(0, 700)

ax_2015.set_xlabel("GDP (x10 to the 13th Power)")
ax_2015.set_ylabel("Suicide Rate per 100K People")

ax_2015.plot(x_axis_2015, y_axis_2015, linewidth=0, marker='o')
ax_2015.plot(x_axis_2015, fit, 'b--')
plt.grid(True)

plt.savefig("Sui_vs_GDP_regression_2015.png")

plt.show()
(t_stat, p) = stats.ttest_ind(x_axis_2015, y_axis_2015, equal_var=False)
p
# Out:
# 2.501178306126408e-05

# %%
su_vs_gdp_2005_df = su_vs_gdp_c_df.query("year == '2005'")
su_vs_gdp_2005_nous_df = su_vs_gdp_2005_df.query("country != 'United States'")
su_vs_gdp_2005_nous_df.head()
# Out:
#      Unnamed: 0             country-year              country  year  \
# 16           16              Albania2005              Albania  2005
# 40           40  Antigua and Barbuda2005  Antigua and Barbuda  2005
# 69           69            Argentina2005            Argentina  2005
# 112         112                Aruba2005                Aruba  2005
# 169         169              Austria2005              Austria  2005
#
#      suicides_no  population  suicides/100k pop      year_gdp  \
# 16             0     2783320               0.00    8160000000
# 40             0       80809               0.00    1020000000
# 69          3058    35550617             128.18  199000000000
# 112           10       93728              99.58    2330000000
# 169         1399     7827461             235.25  316000000000
#
#     gdp_per_capita ($)
# 16          $2,931.00
# 40         $12,649.00
# 69          $5,590.00
# 112        $24,870.00
# 169        $40,367.00

# %%
x_axis_2005 = su_vs_gdp_2005_nous_df['year_gdp']
y_axis_2005 = su_vs_gdp_2005_nous_df['suicides/100k pop']

plt.grid(True)

plt.savefig("Sui_vs_GDP_Scatter_2005.png")

plt.scatter(x_axis_2005, y_axis_2005)

# %%
(slope, intercept, _, _, _) = linregress(x_axis_2005, y_axis_2005)
fit = slope * x_axis_2005 + intercept

# %%
fig, ax_2005 = plt.subplots()

fig.suptitle("Suicide Rate vs GDP Regression 2005", fontsize=16, fontweight="bold")

ax_2005.set_xlim(0, 4500000000000)
ax_2005.set_ylim(0, 700)

ax_2005.set_xlabel("GDP (x10 to the 13th Power)")
ax_2005.set_ylabel("Suicide Rate per 100K People")

ax_2005.plot(x_axis_2005, y_axis_2005, linewidth=0, marker='o')
ax_2005.plot(x_axis_2005, fit, 'b--')
plt.grid(True)

plt.savefig("Sui_vs_GDP_regression_2005.png")

plt.show()
(t_stat, p) = stats.ttest_ind(x_axis_2005, y_axis_2005, equal_var=False)
p
# Out:
# 0.00016372935198783524

# %%
x_axis_capita_2015 = su_vs_gdp_2015_df['gdp_per_capita ($)']
y_axis_capita_2015 = su_vs_gdp_2015_df['suicides/100k pop']

(slope, intercept, _, _, _) = linregress(x_axis_capita_2015, y_axis_capita_2015)
fit = slope * x_axis_capita_2015 + intercept

fig, ax_2015 = plt.subplots()

fig.suptitle("Suicide Rate vs GDP Regression 2015", fontsize=16, fontweight="bold")

cap_2015.set_xlim(0, 4500000000000)
cap_2015.set_ylim(0, 700)

cap_2015.set_xlabel("GDP (x10 to the 13th Power)")
cap_2015.set_ylabel("Suicide Rate per 100K People")

cap_2015.plot(x_axis_capita_2015, y_axis_capita_2015, linewidth=0, marker='o')
cap_2015.plot(x_axis_capita_2015, fit, 'b--')
plt.grid(True)

plt.savefig("Sui_vs_GDP_regression_2015.png")

plt.show()
(t_stat, p) = stats.ttest_ind(x_axis_capita_2015, y_axis_capita_2015, equal_var=False)
p
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-02a0022b7a4a> in <module>
#       2 y_axis_capita_2015 = su_vs_gdp_2015_df['suicides/100k pop']
#       3
# ----> 4 (slope, intercept, _, _, _) = linregress(x_axis_capita_2015, y_axis_capita_2015)
#       5 fit = slope * x_axis_capita_2015 + intercept
#       6
#
# ~\anaconda\Anaconda3\lib\site-packages\scipy\stats\_stats_mstats_common.py in linregress(x, y)
#      87
#      88     n = len(x)
# ---> 89     xmean = np.mean(x, None)
#      90     ymean = np.mean(y, None)
#      91
#
# ~\anaconda\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py in mean(a, axis, dtype, out, keepdims)
#    2918
#    2919     return _methods._mean(a, axis=axis, dtype=dtype,
# -> 2920                           out=out, **kwargs)
#    2921
#    2922
#
# ~\anaconda\Anaconda3\lib\site-packages\numpy\core\_methods.py in _mean(a, axis, dtype, out, keepdims)
#      85             ret = ret.dtype.type(ret / rcount)
#      86     else:
# ---> 87         ret = ret / rcount
#      88
#      89     return ret
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %%
countries_pd = su_vs_gdp_2015_df
countries_pd["Lat"] = ""
countries_pd["Lng"] = ""
countries_pd.head(100)

# %%
from gconfig import (gkey)
gmaps.configure(api_key=gkey)

# %%
params = {"key": gkey}

for index, row in countries_pd.iterrows():
    base_url = "https://maps.googleapis.com/maps/api/geocode/json"

    country = row['country'] 
    params['address'] = f"{country}"
    country_lat_lng = requests.get(base_url, params=params)
    country_lat_lng = country_lat_lng.json()

    countries_pd.loc[index, "Lat"] = country_lat_lng["results"][0]["geometry"]["location"]["lat"]
    countries_pd.loc[index, "Lng"] = country_lat_lng["results"][0]["geometry"]["location"]["lng"]

countries_pd.head(50)

# %%
countries_pd.to_csv('country_vs_suicide_rate_2015.csv')

# %%
#checkpoint
file_gdp3 = "country_vs_suicide_rate_2015.csv"

countries_pd = pd.read_csv(file_gdp3)
countries_pd.head()

# %%
plt.scatter(countries_pd["Lat"], 
            countries_pd["suicides/100k pop"], 
            marker="o", alpha=0.8, edgecolors='black')

#set graph properties
plt.title(f"Latitiude vs. Suicide Rate")
plt.ylabel("Suicide Rate per 100K People for 2015")
plt.xlabel("Latitude")
plt.grid(True)

#save image
plt.savefig("Sui_vs_Lat.png")

#show
plt.show()

# %%
x_axis2 = countries_pd["Lat"]
y_axis2 = countries_pd["suicides/100k pop"]

(slope, intercept, _, _, _) = linregress(x_axis2, y_axis2)
fit = slope * x_axis2 + intercept

fig, ax2 = plt.subplots()

fig.suptitle("Suicide Rate vs Latitude Regression 2015", fontsize=16, fontweight="bold")

ax2.set_xlabel("Latitude")
ax2.set_ylabel("Suicide Rate per 100K People")

ax2.plot(x_axis2, y_axis2, linewidth=0, marker='o')
ax2.plot(x_axis2, fit, 'b--')

plt.grid(True)

plt.savefig("Sui_vs_Lat_regression.png")

plt.show()

# %%
(t_stat, p2) = stats.ttest_ind(x_axis2, y_axis2, equal_var=False)
p2

# %%
gmaps.configure(api_key=gkey)

# %%
# Create a poverty Heatmap layer

import gmaps
import gmaps.datasets
gmaps.configure(api_key=gkey)

map_df = countries_pd[["Lat", "Lng", "suicides/100k pop"]]

fig = gmaps.figure(map_type='HYBRID', zoom_level=2, center=(20,-30))

heatmap_layer = gmaps.heatmap_layer(
    map_df[["Lat", "Lng"]], 
    weights = map_df["suicides/100k pop"],
    max_intensity = 200, 
    point_radius=20.0
)
fig.add_layer(heatmap_layer)

fig

# %%
locations
